# %% [markdown]
# Najeeb ur rehmasn
#
# Reg No 0192

# %%
import pandas as pd

# %% [markdown]
# Read the CSV file

# %%
df=pd.read_csv("immo_data.csv")

# %% [markdown]
# print the data frame

# %%
df
# Out:
#                      regio1  serviceCharge                     heatingType  \
# 0       Nordrhein_Westfalen         245.00                 central_heating
# 1           Rheinland_Pfalz         134.00  self_contained_central_heating
# 2                   Sachsen         255.00                   floor_heating
# 3                   Sachsen          58.15                district_heating
# 4                    Bremen         138.00  self_contained_central_heating
# ...                     ...            ...                             ...
# 268845               Bayern          90.00                       heat_pump
# 268846               Hessen         220.00                     gas_heating
# 268847               Hessen         220.00                 central_heating
# 268848  Nordrhein_Westfalen         175.00                       heat_pump
# 268849               Hessen         315.00                 central_heating
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   regio1                    268850 non-null  object
#  1   serviceCharge             261941 non-null  float64
#  2   heatingType               223994 non-null  object
#  3   telekomTvOffer            236231 non-null  object
#  4   telekomHybridUploadSpeed  45020 non-null   float64
#  5   newlyConst                268850 non-null  bool
#  6   balcony                   268850 non-null  bool
#  7   picturecount              268850 non-null  int64
#  8   pricetrend                267018 non-null  float64
#  9   telekomUploadSpeed        235492 non-null  float64
#  10  totalRent                 228333 non-null  float64
#  11  yearConstructed           211805 non-null  float64
#  12  scoutId                   268850 non-null  int64
# ...

# %%
df.describe()
# Out:
#        serviceCharge  telekomHybridUploadSpeed   picturecount     pricetrend  \
# count  261941.000000                   45020.0  268850.000000  267018.000000
# mean      151.206113                      10.0       9.791958       3.389001
# std       308.295790                       0.0       6.408399       1.964874
# min         0.000000                      10.0       0.000000     -12.330000
# 25%        95.000000                      10.0       6.000000       2.000000
# 50%       135.000000                      10.0       9.000000       3.390000
# 75%       190.000000                      10.0      13.000000       4.570000
# max    146118.000000                      10.0     121.000000      14.920000
#
#        telekomUploadSpeed     totalRent  yearConstructed       scoutId  \
# count       235492.000000  2.283330e+05    211805.000000  2.688500e+05
# mean            28.804928  9.013315e+02      1966.400590  1.069697e+08
# ...

# %%
df.columns
# Out:
# Index(['regio1', 'serviceCharge', 'heatingType', 'telekomTvOffer',
#        'telekomHybridUploadSpeed', 'newlyConst', 'balcony', 'picturecount',
#        'pricetrend', 'telekomUploadSpeed', 'totalRent', 'yearConstructed',
#        'scoutId', 'noParkSpaces', 'firingTypes', 'hasKitchen', 'geo_bln',
#        'cellar', 'yearConstructedRange', 'baseRent', 'houseNumber',
#        'livingSpace', 'geo_krs', 'condition', 'interiorQual', 'petsAllowed',
#        'street', 'streetPlain', 'lift', 'baseRentRange', 'typeOfFlat',
#        'geo_plz', 'noRooms', 'thermalChar', 'floor', 'numberOfFloors',
#        'noRoomsRange', 'garden', 'livingSpaceRange', 'regio2', 'regio3',
#        'description', 'facilities', 'heatingCosts', 'energyEfficiencyClass',
#        'lastRefurbish', 'electricityBasePrice', 'electricityKwhPrice', 'date'],
#       dtype='object')

# %% [markdown]
# Rename the Column name

# %%
df.rename(columns={"serviceCharge":"charges"})
# Out:
#                      regio1  charges                     heatingType  \
# 0       Nordrhein_Westfalen   245.00                 central_heating
# 1           Rheinland_Pfalz   134.00  self_contained_central_heating
# 2                   Sachsen   255.00                   floor_heating
# 3                   Sachsen    58.15                district_heating
# 4                    Bremen   138.00  self_contained_central_heating
# ...                     ...      ...                             ...
# 268845               Bayern    90.00                       heat_pump
# 268846               Hessen   220.00                     gas_heating
# 268847               Hessen   220.00                 central_heating
# 268848  Nordrhein_Westfalen   175.00                       heat_pump
# 268849               Hessen   315.00                 central_heating
#
#        telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  \
# ...

# %%
df.columns
# Out:
# Index(['regio1', 'serviceCharge', 'heatingType', 'telekomTvOffer',
#        'telekomHybridUploadSpeed', 'newlyConst', 'balcony', 'picturecount',
#        'pricetrend', 'telekomUploadSpeed', 'totalRent', 'yearConstructed',
#        'scoutId', 'noParkSpaces', 'firingTypes', 'hasKitchen', 'geo_bln',
#        'cellar', 'yearConstructedRange', 'baseRent', 'houseNumber',
#        'livingSpace', 'geo_krs', 'condition', 'interiorQual', 'petsAllowed',
#        'street', 'streetPlain', 'lift', 'baseRentRange', 'typeOfFlat',
#        'geo_plz', 'noRooms', 'thermalChar', 'floor', 'numberOfFloors',
#        'noRoomsRange', 'garden', 'livingSpaceRange', 'regio2', 'regio3',
#        'description', 'facilities', 'heatingCosts', 'energyEfficiencyClass',
#        'lastRefurbish', 'electricityBasePrice', 'electricityKwhPrice', 'date'],
#       dtype='object')

# %% [markdown]
# check unique values

# %%
df.nunique()
# Out:
# regio1                          16
# serviceCharge                12266
# heatingType                     13
# telekomTvOffer                   3
# telekomHybridUploadSpeed         1
# newlyConst                       2
# balcony                          2
# picturecount                    95
# pricetrend                    1234
# telekomUploadSpeed               7
# totalRent                    28486
# yearConstructed                465
# scoutId                     268850
# noParkSpaces                    71
# firingTypes                    132
# hasKitchen                       2
# geo_bln                         16
# cellar                           2
# yearConstructedRange             9
# baseRent                     26659
# houseNumber                   5510
# livingSpace                  13005
# geo_krs                        419
# condition                       10
# interiorQual                     4
# petsAllowed                      3
# street                       52373
# ...

# %% [markdown]
# Count Null

# %%
df.isnull().sum()
# Out:
# regio1                           0
# serviceCharge                 6909
# heatingType                  44856
# telekomTvOffer               32619
# telekomHybridUploadSpeed    223830
# newlyConst                       0
# balcony                          0
# picturecount                     0
# pricetrend                    1832
# telekomUploadSpeed           33358
# totalRent                    40517
# yearConstructed              57045
# scoutId                          0
# noParkSpaces                175798
# firingTypes                  56964
# hasKitchen                       0
# geo_bln                          0
# cellar                           0
# yearConstructedRange         57045
# baseRent                         0
# houseNumber                  71018
# livingSpace                      0
# geo_krs                          0
# condition                    68489
# interiorQual                112665
# petsAllowed                 114573
# street                           0
# ...

# %% [markdown]
# use not null to check not null cell is true and other is false

# %%
df.notnull()
# Out:
#         regio1  serviceCharge  heatingType  telekomTvOffer  \
# 0         True           True         True            True
# 1         True           True         True            True
# 2         True           True         True            True
# 3         True           True         True            True
# 4         True           True         True           False
# ...        ...            ...          ...             ...
# 268845    True           True         True            True
# 268846    True           True         True           False
# 268847    True           True         True            True
# 268848    True           True         True           False
# 268849    True           True         True           False
#
#         telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0                          False        True     True          True
# 1                          False        True     True          True
# ...

# %% [markdown]
# remove duplicates

# %%
df.drop_duplicates()
# Out:
#                      regio1  serviceCharge                     heatingType  \
# 0       Nordrhein_Westfalen         245.00                 central_heating
# 1           Rheinland_Pfalz         134.00  self_contained_central_heating
# 2                   Sachsen         255.00                   floor_heating
# 3                   Sachsen          58.15                district_heating
# 4                    Bremen         138.00  self_contained_central_heating
# ...                     ...            ...                             ...
# 268845               Bayern          90.00                       heat_pump
# 268846               Hessen         220.00                     gas_heating
# 268847               Hessen         220.00                 central_heating
# 268848  Nordrhein_Westfalen         175.00                       heat_pump
# 268849               Hessen         315.00                 central_heating
#
# ...

# %% [markdown]
# Handling Missing data

# %% [markdown]
# dropna remove rows with missing values
#
# fillna (value) fill mising value with the specified value

# %%
print("before  ")
print(df.shape) 
print("After  ")
# Drop columns with any missing values
df.dropna(axis='columns', inplace=True)
# Print new DataFrame shape  
print(df.shape)
# Out:
# before
# (33, 49)
# After
# (33, 49)
# C:\Users\m-reh\AppData\Local\Temp\ipykernel_13116\3879674959.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis='columns', inplace=True)

# %%
df=df.dropna()

# %%
df
# Out:
#                         regio1  serviceCharge                     heatingType  \
# 9226                    Hessen          38.78                district_heating
# 33285      Nordrhein_Westfalen          60.00  self_contained_central_heating
# 60721      Nordrhein_Westfalen          80.00                 central_heating
# 63645       Schleswig_Holstein          95.00                 central_heating
# 75928              Brandenburg          45.00                 central_heating
# 78585           Sachsen_Anhalt          58.00                 central_heating
# 111129          Sachsen_Anhalt          87.67                 central_heating
# 126613     Nordrhein_Westfalen         100.00                 central_heating
# 130614     Nordrhein_Westfalen         135.00                 central_heating
# 145039     Nordrhein_Westfalen         250.90                   floor_heating
# 154324                  Berlin         300.00                   floor_heating
# ...

# %%
df.fillna("nn")
# Out:
#                         regio1  serviceCharge                     heatingType  \
# 9226                    Hessen          38.78                district_heating
# 33285      Nordrhein_Westfalen          60.00  self_contained_central_heating
# 60721      Nordrhein_Westfalen          80.00                 central_heating
# 63645       Schleswig_Holstein          95.00                 central_heating
# 75928              Brandenburg          45.00                 central_heating
# 78585           Sachsen_Anhalt          58.00                 central_heating
# 111129          Sachsen_Anhalt          87.67                 central_heating
# 126613     Nordrhein_Westfalen         100.00                 central_heating
# 130614     Nordrhein_Westfalen         135.00                 central_heating
# 145039     Nordrhein_Westfalen         250.90                   floor_heating
# 154324                  Berlin         300.00                   floor_heating
# ...

# %% [markdown]
# there is no null value presnt all are false

# %%
print(df.isnull())
# Out:
#         regio1  serviceCharge  heatingType  telekomTvOffer  \
# 9226     False          False        False           False
# 33285    False          False        False           False
# 60721    False          False        False           False
# 63645    False          False        False           False
# 75928    False          False        False           False
# 78585    False          False        False           False
# 111129   False          False        False           False
# 126613   False          False        False           False
# 130614   False          False        False           False
# 145039   False          False        False           False
# 154324   False          False        False           False
# 162289   False          False        False           False
# 165766   False          False        False           False
# 167854   False          False        False           False
# 182472   False          False        False           False
# ...

# %%
print(df.isnull().sum())
# Out:
# regio1                      0
# serviceCharge               0
# heatingType                 0
# telekomTvOffer              0
# telekomHybridUploadSpeed    0
# newlyConst                  0
# balcony                     0
# picturecount                0
# pricetrend                  0
# telekomUploadSpeed          0
# totalRent                   0
# yearConstructed             0
# scoutId                     0
# noParkSpaces                0
# firingTypes                 0
# hasKitchen                  0
# geo_bln                     0
# cellar                      0
# yearConstructedRange        0
# baseRent                    0
# houseNumber                 0
# livingSpace                 0
# geo_krs                     0
# condition                   0
# interiorQual                0
# petsAllowed                 0
# street                      0
# streetPlain                 0
# lift                        0
# baseRentRange               0
# typeOfFlat                  0
# ...
